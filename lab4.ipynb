# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dframe = pd.read_csv('marketing_customer_analysis.csv')

# %%
dframe.dtypes

# %%
numerical = dframe.select_dtypes(np.number)
numerical.columns

# %%
categorical = dframe.select_dtypes(np.object)

# %%
sns.distplot(numerical['Customer Lifetime Value'], bins=20)
plt.show()

# %%
sns.distplot(numerical['Income'], bins=20)
plt.show()

# %%
sns.distplot(numerical['Monthly Premium Auto'], bins=20)
plt.show()

# %%
sns.distplot(numerical['Months Since Last Claim'], bins=20)
plt.show()

# %%
sns.distplot(numerical['Months Since Policy Inception'], bins=20)
plt.show()

# %%
sns.distplot(numerical['Number of Open Complaints'], bins=20)
plt.show()

# %%
sns.distplot(numerical['Number of Policies'], bins=20)
plt.show()

# %%
sns.distplot(numerical['Total Claim Amount'], bins=20)
plt.show()

# %% [markdown]
#                 They don't look like normal distribution

# %%
dframe['Customer Lifetime Value'].hist()
plt.show()

# %%
dframe['Income'].hist()
plt.show()

# %%
corr_matrix = dframe.corr()
mask = np.zeros_like(corr_matrix)
mask[np.triu_indices_from(mask)] = True
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(corr_matrix, mask=mask, annot=True)
plt.show()

# %%
import pandas as pd

from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
Y = numerical['Total Claim Amount']
X = numerical.drop(['Total Claim Amount'], axis=1)
X = sm.add_constant(X)
model = sm.OLS(Y,X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     Total Claim Amount   R-squared:                       0.519
# Model:                            OLS   Adj. R-squared:                  0.518
# Method:                 Least Squares   F-statistic:                     1405.
# Date:                Wed, 13 Jan 2021   Prob (F-statistic):               0.00
# Time:                        17:23:53   Log-Likelihood:                -61425.
# No. Observations:                9134   AIC:                         1.229e+05
# Df Residuals:                    9126   BIC:                         1.229e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                            72.3910      8.744      8.279      0.000      55.252      89.530
# ...

# %%
Y = numerical['Total Claim Amount']
X = numerical.drop(['Total Claim Amount'], axis=1)
lm = linear_model.LinearRegression()
lm.fit(X,Y)
print("R2 = ",round(lm.score(X,Y),2))
# Out:
# R2 =  0.52
